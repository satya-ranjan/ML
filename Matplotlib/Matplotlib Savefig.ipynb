# %% [markdown]
# # How to save figure (plot and Chars)?

# %%
import matplotlib.pyplot as plt

# %%
plt.pie([40,30,20])
plt.savefig("pie_chart")

plt.show()

# %%
plt.pie([40,30,20])
plt.savefig("pie_chart", quality = 99,facecolor = "g")

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_8620/2002385461.py:2: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("pie_chart", quality = 99,facecolor = "g")
