# %% [markdown]
# # How to write CSV file #3

# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\ML\\ML\\Pandas\\Fortune 500 2017 - Fortune 500.csv")
df
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# ...

# %%
df.head() # It will print first 5 rows
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
df.head(1) # It will print 1 row
# Out:
#    Rank    Title                 Website  Employees     Sector  \
# 0     1  Walmart  http://www.walmart.com    2300000  Retailing
#
#                 Industry       Hqlocation               Hqaddr       Hqcity  \
# 0  General Merchandisers  Bentonville, AR  702 S.W. Eighth St.  Bentonville
#
#   Hqstate  ...                                      Ceo-title  \
# 0      AR  ...  President, Chief Executive Officer & Director
#
#                                       Address Ticker               Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT  Wal-Mart Stores, Inc.
#
#   Revenues Revchange Profits  Prftchange  Assets  Totshequity
# 0   485873       0.8   13643        -7.2  198825        77798
#
# [1 rows x 23 columns]

# %%
df.head(8) # it will print 8 rows
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# 1              Financials  Insurance: Property and Casualty (Stock)
# 2              Technology               Computers, Office Equipment
# ...

# %%
df.tail() # It will print last 5 rows
# Out:
#    Rank               Title                           Website  Employees  \
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 5             Health Care   Health Care: Insurance and Managed Care
# 6             Health Care  Health Care: Pharmacy and Other Services
# 7  Motor Vehicles & Parts                  Motor Vehicles and Parts
# 8      Telecommunications                        Telecommunications
# 9  Motor Vehicles & Parts                  Motor Vehicles and Parts
#
#        Hqlocation                  Hqaddr      Hqcity Hqstate  ...  \
# ...

# %%
df.tail(2) # It will print last 2 rows
# Out:
#    Rank       Title              Website  Employees                  Sector  \
# 8     9        AT&T   http://www.att.com     268540      Telecommunications
# 9    10  Ford Motor  http://www.ford.com     201000  Motor Vehicles & Parts
#
#                    Industry    Hqlocation            Hqaddr    Hqcity Hqstate  \
# 8        Telecommunications    Dallas, TX  208 S. Akard St.    Dallas      TX
# 9  Motor Vehicles and Parts  Dearborn, MI    1 American Rd.  Dearborn      MI
#
#    ...                                      Ceo-title  \
# 8  ...  Chairman, President & Chief Executive Officer
# 9  ...  President, Chief Executive Officer & Director
#
#                               Address Ticker            Fullname Revenues  \
# 8  208 S. Akard St., Dallas, TX 75202      T           AT&T Inc.   163786
# 9  1 American Rd., Dearborn, MI 48126      F  Ford Motor Company   151800
#
#   Revchange Profits  Prftchange  Assets  Totshequity
# 8      11.6   12976        -2.8  403821       123135
# ...

# %%
df = pd.read_csv("E:\\ML\\ML\\Pandas\\Fortune 500 2017 - Fortune 500.csv",dtype = {"Rank": "float64"})
df                                                                # To change the data type of a singe columns
# Out:
#    Rank               Title                           Website  Employees  \
# 0   1.0             Walmart            http://www.walmart.com    2300000
# 1   2.0  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2   3.0               Apple              http://www.apple.com     116000
# 3   4.0         Exxon Mobil         http://www.exxonmobil.com      72700
# 4   5.0            McKesson           http://www.mckesson.com      68000
# 5   6.0  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6   7.0          CVS Health          http://www.cvshealth.com     204000
# 7   8.0      General Motors                 http://www.gm.com     225000
# 8   9.0                AT&T                http://www.att.com     268540
# 9  10.0          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# ...

# %%
df = pd.read_csv("E:\\ML\\ML\\Pandas\\Fortune 500 2017 - Fortune 500.csv",dtype={"Rank":"float64","Employees":"float64"}) # It will convort 2 rows at a time
df
# Out:
#    Rank               Title                           Website  Employees  \
# 0   1.0             Walmart            http://www.walmart.com  2300000.0
# 1   2.0  Berkshire Hathaway  http://www.berkshirehathaway.com   367700.0
# 2   3.0               Apple              http://www.apple.com   116000.0
# 3   4.0         Exxon Mobil         http://www.exxonmobil.com    72700.0
# 4   5.0            McKesson           http://www.mckesson.com    68000.0
# 5   6.0  UnitedHealth Group  http://www.unitedhealthgroup.com   230000.0
# 6   7.0          CVS Health          http://www.cvshealth.com   204000.0
# 7   8.0      General Motors                 http://www.gm.com   225000.0
# 8   9.0                AT&T                http://www.att.com   268540.0
# 9  10.0          Ford Motor               http://www.ford.com   201000.0
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# ...
